# %%
import pandas as pd
import numpy as np

# %%
routes_df = pd.read_csv('routes.csv')
aircraft_df = pd.read_csv('aircraft_data_modified.csv')
planes_df = pd.read_csv('planes.dat.csv', header = None)

routes_df.head()
# Out:
#   airline airline ID  source airport  source airport id  destination apirport  \
# 0      2B        410             AER               2965                   KZN
# 1      2B        410             ASF               2966                   KZN
# 2      2B        410             ASF               2966                   MRV
# 3      2B        410             CEK               2968                   KZN
# 4      2B        410             CEK               2968                   OVB
#
#    destination airport id  codeshare   stops  equipment
# 0                    2990        NaN       0        CR2
# 1                    2990        NaN       0        CR2
# 2                    2962        NaN       0        CR2
# 3                    2990        NaN       0        CR2
# 4                    4078        NaN       0        CR2

# %%
aircraft_df.head()
# Out:
#   ICAO_code classification  pob_num
# 0      A002            G1P      3.0
# 1        A1            L1P      1.0
# 2       A10            L2J      1.0
# 3      A109            H2T      8.0
# 4      A119            H1T      9.0

# %%
planes_df.head()
# Out:
#      0                                             1    2     3
# 0  NaN                       Aerospatiale (Nord) 262  ND2  N262
# 1  0.0  Aerospatiale (Sud Aviation) Se.210 Caravelle  CRV  S210
# 2  1.0                  Aerospatiale SN.601 Corvette  NDC  S601
# 3  2.0                Aerospatiale/Alenia ATR 42-300  AT4  AT43
# 4  3.0                Aerospatiale/Alenia ATR 42-500  AT5  AT45

# %%
merged_aircraft_planes = pd.merge(aircraft_df, planes_df, left_on='ICAO_code', right_on=3)
merged_aircraft_planes.drop(columns=[3,0], inplace=True)

merged_aircraft_planes.columns=['long_plane_code', 'classification', 'capacity', 'plane_type', 'short_code']
merged_aircraft_planes.head()
# Out:
#   long_plane_code classification  capacity             plane_type short_code
# 0            A124            L4J      88.0  Antonov AN-124 Ruslan        A4F
# 1            A140            L2T      54.0         Antonov AN-140        A40
# 2            A148            L2J      80.0         Antonov An-148        A81
# 3            A158            L2J      99.0         Antonov An-158        A58
# 4            A19N            L2J     180.0         Airbus A319neo        31N

# %%
list(routes_df[' equipment'].unique())
# Out:
# ['CR2',
#  'A81',
#  'AN4',
#  '142',
#  '142 141',
#  '141',
#  '143',
#  '143 146',
#  '142 146',
#  '146',
#  'CRJ',
#  'E70 CRJ M87',
#  'M87',
#  'M87 CRJ',
#  '319',
#  '319 320',
#  '320 319',
#  '100',
#  'ATP',
#  'SF3',
#  'ATP SF3',
#  'ATR',
#  'SF3 ATP',
#  'BNI',
#  'DH4',
#  '320',
#  '330',
#  'DH3',
#  'AT7',
#  'CNC',
#  'DHP',
#  'DH8',
#  'DHT BET',
#  'DHT',
#  '73M',
#  'BET',
#  'DHT DH8',
#  'DH8 DHT',
#  'DH8 BET',
#  'BET DH8',
#  '737',
#  'SF3 ',
#  'SH6',
#  'SU9',
#  '734',
#  'SU9 73G',
#  'AT5',
#  'AT5 320',
#  '321',
#  '321 320',
#  '321 320 330',
#  '319 321',
#  '321 319 320',
#  '330 319',
#  '330 321 320',
#  '321 330',
#  '320 321',
#  '319 330',
#  '319 321 320',
#  '330 321',
#  'PL2',
#  'E70',
#  'PAG',
#  'YK2',
#  '73G',
#  'TU5',
#  '73G TU5',
#  'YK4',
#  '313',
#  '777',
#  '777 763',
#  '763',
#  'CRJ 319',
#  '319 CRJ',
#  '319 320 CRJ',
#  'CRJ 319 320',
#  'CRJ 320',
#  '320 319 CRJ',
#  'PA2',
#  'CN1',
#  'CNA',
#  'CNA DHT',
# ...

# %%
routes_df.columns = ['airline', 'airline_ID', 'source_airport', 'source_airport_ID', 'destination_airport', 'destination_airport_ID','codeshare', 'stops', 'short_plane_code']
routes_df.head()
# Out:
#   airline airline_ID source_airport source_airport_ID destination_airport  \
# 0      2B        410            AER              2965                 KZN
# 1      2B        410            ASF              2966                 KZN
# 2      2B        410            ASF              2966                 MRV
# 3      2B        410            CEK              2968                 KZN
# 4      2B        410            CEK              2968                 OVB
#
#   destination_airport_ID codeshare  stops short_plane_code
# 0                   2990       NaN      0              CR2
# 1                   2990       NaN      0              CR2
# 2                   2962       NaN      0              CR2
# 3                   2990       NaN      0              CR2
# 4                   4078       NaN      0              CR2

# %%
routes_df['short_code'] = routes_df['short_plane_code'].str.split().str[-1].str[-3:]

routes_df.head()
# Out:
#   airline airline_ID source_airport source_airport_ID destination_airport  \
# 0      2B        410            AER              2965                 KZN
# 1      2B        410            ASF              2966                 KZN
# 2      2B        410            ASF              2966                 MRV
# 3      2B        410            CEK              2968                 KZN
# 4      2B        410            CEK              2968                 OVB
#
#   destination_airport_ID codeshare  stops short_plane_code short_code
# 0                   2990       NaN      0              CR2        CR2
# 1                   2990       NaN      0              CR2        CR2
# 2                   2962       NaN      0              CR2        CR2
# 3                   2990       NaN      0              CR2        CR2
# 4                   4078       NaN      0              CR2        CR2

# %%
list(routes_df['short_code'].unique())
# Out:
# ['CR2',
#  'A81',
#  'AN4',
#  '142',
#  '141',
#  '143',
#  '146',
#  'CRJ',
#  'M87',
#  '319',
#  '320',
#  '100',
#  'ATP',
#  'SF3',
#  'ATR',
#  'BNI',
#  'DH4',
#  '330',
#  'DH3',
#  'AT7',
#  'CNC',
#  'DHP',
#  'DH8',
#  'BET',
#  'DHT',
#  '73M',
#  '737',
#  'SH6',
#  'SU9',
#  '734',
#  '73G',
#  'AT5',
#  '321',
#  'PL2',
#  'E70',
#  'PAG',
#  'YK2',
#  'TU5',
#  'YK4',
#  '313',
#  '777',
#  '763',
#  'PA2',
#  'CN1',
#  'CNA',
#  '735',
#  'AT4',
#  '733',
#  'BE1',
#  'FRJ',
#  'EMB',
#  'BEH',
#  '738',
#  'TU3',
#  'E90',
#  'CNT',
#  'M83',
#  'F50',
#  'MA6',
#  '752',
#  'D28',
#  'EM2',
#  nan,
#  'M82',
#  '767',
#  '332',
#  '747',
#  'CR9',
#  'DH1',
#  'D38',
#  'L4T',
#  'ER4',
#  '732',
#  '73W',
#  '73H',
#  '739',
#  '333',
#  '77W',
#  '772',
#  '736',
#  'SWM',
#  'CR7',
#  'CRK',
#  'M80',
#  'E75',
#  '744',
#  'ERD',
#  '340',
#  '757',
#  '787',
#  '380',
#  '773',
#  '762',
#  '318',
#  '32B',
#  '346',
#  'AR8',
#  '32A',
#  '73C',
#  'ERJ',
# ...

# %%
final_df = pd.merge(routes_df, merged_aircraft_planes[['short_code', 'capacity']], how='left', on='short_code')

print(final_df)
# Out:
#       airline airline_ID source_airport source_airport_ID destination_airport  \
# 0          2B        410            AER              2965                 KZN
# 1          2B        410            ASF              2966                 KZN
# 2          2B        410            ASF              2966                 MRV
# 3          2B        410            CEK              2968                 KZN
# 4          2B        410            CEK              2968                 OVB
# ...       ...        ...            ...               ...                 ...
# 67778      ZL       4178            WYA              6334                 ADL
# 67779      ZM      19016            DME              4029                 FRU
# 67780      ZM      19016            FRU              2912                 DME
# 67781      ZM      19016            FRU              2912                 OSS
# 67782      ZM      19016            OSS              2913                 FRU
#
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67783 entries, 0 to 67782
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   airline                 67783 non-null  object
#  1   airline_ID              67783 non-null  object
#  2   source_airport          67783 non-null  object
#  3   source_airport_ID       67783 non-null  object
#  4   destination_airport     67783 non-null  object
#  5   destination_airport_ID  67783 non-null  object
#  6   codeshare               14633 non-null  object
#  7   stops                   67783 non-null  int64
#  8   short_plane_code        67765 non-null  object
#  9   short_code              67765 non-null  object
#  10  capacity                51606 non-null  float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 6.2+ MB

# %%
(final_df['capacity'].value_counts())
# Out:
# 179.0    11658
# 189.0     8799
# 142.0     5322
# 212.0     2082
# 50.0      2030
#          ...
# 109.0        6
# 93.0         4
# 5.0          4
# 410.0        4
# 64.0         1
# Name: capacity, Length: 76, dtype: int64

# %%
capacity_inserts = {
    '146': 27,
    'CRJ': 70,
    '330': 260,
    'CNC': 12,
    'DH8': 40,
    'BET': 10,
    '73M': 149,
    '737': 189,
    'YK2': 104,
    'YK4': 25,
    '313': 200,
    '777': 375,
    'CNA': 7,
    'BE1': 10,
    'CNT': 10,
    'MA6': 65
}

capacities = []

final_df.dropna(subset='short_code', inplace=True)

final_df['capacity'].fillna(0, inplace=True)
count = 0

for row in final_df.iterrows():
    if row[1]['capacity'] != 0:
        capacities.append(row[1]['capacity'])
        count += 1
    else:
        try:
            capacities.append(capacity_inserts[row[1]['short_code']])
        except:
            capacities.append(np.median(final_df['capacity'].dropna()))
        count += 1

        
print(count)
# Out:
# 67765

# %%
final_df['capacity'] = capacities
#del final_df['stops']
#del final_df['codeshare']

# %%
def airport_filter(code):
    
    airports = {
    'BHM': 'Birmingham International Airport',
    'DHN': 'Dothan Regional Airport',
    'HSV': 'Huntsville International Airport',
    'MOB': 'Mobile',
    'MGM': 'Montgomery',
    'ANC': 'Anchorage International Airport',
    'FAI': 'Fairbanks International Airport',
    'JNU': 'Juneau International Airport',
    'FLG': 'Flagstaff',
    'PHX': 'Phoenix Sky Harbor International Airport',
    'TUS': 'Tucson International Airport',
    'YUM': 'Yuma International Airport',
    'FYV': 'Fayetteville',
    'LIT': 'Little Rock National Airport',
    'XNA': 'Northwest Arkansas Regional Airport',
    'BUR': 'Burbank',
    'FAT': 'Fresno',
    'LGB': 'Long Beach',
    'LAX': 'Los Angeles International Airport',
    'OAK': 'Oakland',
    'ONT': 'Ontario',
    'PSP': 'Palm Springs',
    'SAN': 'San Diego',
    'SFO': 'San Francisco International Airport',
    'SJC': 'San Jose',
    'SNA': 'Santa Ana',
    'ASE': 'Aspen',
    'COS': 'Colorado Springs',
    'DEN': 'Denver International Airport',
    'GJT': 'Grand Junction',
    'PUB': 'Pueblo',
    'ATL': 'Hartsfield-Jackson Atlanta International Airport',
    'BDL': 'Hartford',
    'HVN': 'Tweed New Haven',
    'IAD': 'Dulles International Airport',
    'DCA': 'Washington National Airport',
    'DAB': 'Daytona Beach',
    'FLL': 'Fort Lauderdale-Hollywood International Airport',
    'RSW': 'Fort Meyers',
    'JAX': 'Jacksonville',
    'EYK': 'Key West International Airport',
    'MIA': 'Miami International Airport',
    'MCO': 'Orlando',
    'PNS': 'Pensacola',
    'PIE': 'St. Petersburg',
    'SRQ': 'Sarasota',
    'TPA': 'Tampa',
    'PBI': 'West Palm Beach',
    'PFN': 'Panama City-Bay County International Airport',
    'AGS': 'Augusta',
    'SAV': 'Savannah',
    'ITO': 'Hilo',
    'HNL': 'Honolulu International Airport',
    'OGG': 'Kahului',
    'KOA': 'Kailua',
    'LIH': 'Lihue',
    'BOI': 'Boise',
    'MDW': 'Chicago Midway Airport',
    'ORD': 'O’Hare International Airport',
    'MLI': 'Moline',
    'PIA': 'Peoria',
    'EVV': 'Evansville',
    'FWA': 'Fort Wayne',
    'IND': 'Indianapolis International Airport',
    'SBN': 'South Bend',
    'CID': 'Cedar Rapids',
    'DSM': 'Des Moines',
    'ICT': 'Wichita',
    'LEX': 'Lexington',
    'SDF': 'Louisville',
    'BTR': 'Baton Rouge',
    'MSY': 'New Orleans International Airport',
    'SHV': 'Shreveport',
    'AUG': 'Augusta',
    'BGR': 'Bangor',
    'PWM': 'Portland',
    'BWI': 'Baltimore',
    'BOS': 'Logan International Airport',
    'HYA': 'Hyannis',
    'ACK': 'Nantucket',
    'ORH': 'Worcester',
    'BTL': 'Battlecreek',
    'DTW': 'Detroit Metropolitan Airport',
    'DET': 'Detroit',
    'FNT': 'Flint',
    'GRR': 'Grand Rapids',
    'AZO': 'Kalamazoo-Battle Creek International Airport',
    'LAN': 'Lansing',
    'MBS': 'Saginaw',
    'DLH': 'Duluth',
    'MSP': 'Minneapolis/St. Paul International Airport',
    'RST': 'Rochester',
    'GPT': 'Gulfport',
    'JAN': 'Jackson',
    'MCI': 'Kansas City',
    'STL': 'Lambert International Airport',
    'SGF': 'Springfield',
    'BIL': 'Billings',
    'LNK': 'Lincoln',
    'OMA': 'Omaha',
    'LAS': 'Las Vegas McCarran International Airport',
    'RNO': 'Reno-Tahoe International Airport',
    'MHT': 'Manchester',
    'ACY': 'Atlantic City International Airport',
    'EWR': 'Newark International Airport',
    'TTN': 'Trenton',
    'ABQ': 'Albuquerque International Airport',
    'ALM': 'Alamogordo',
    'ALB': 'Albany International Airport',
    'BUF': 'Buffalo',
    'JFK': 'John F. Kennedy International Airport',
    'LGA': 'La Guardia Airport',
    'SYR': 'Syracuse',
    'AVL': 'Asheville',
    'CLT': 'Charlotte/Douglas International Airport',
    'FAY': 'Fayetteville',
    'GSO': 'Greensboro',
    'RDU': 'Raleigh',
    'INT': 'Winston-Salem',
    'BIS': 'Bismark',
    'FAR': 'Fargo',
    'CAK': 'Akron',
    'CVG': 'Cincinnati',
    'CLE': 'Cleveland',
    'CMH': 'Columbus',
    'DAY': 'Dayton',
    'TOL': 'Toledo',
    'OKC': 'Oklahoma City',
    'TUL': 'Tulsa',
    'EUG': 'Eugene',
    'PDX': 'Portland International Airport',
    'HIO': 'Hillsboro Airport',
    'SLE': 'Salem',
    'ABE': 'Allentown',
    'ERI': 'Erie',
    'MDT': 'Harrisburg',
    'PHL': 'Philadelphia',
    'PIT': 'Pittsburgh',
    'AVP': 'Scranton',
    'PVD': 'Providence - T.F. Greenland Airport',
    'CHS': 'Charleston',
    'CAE': 'Columbia',
    'GSP': 'Greenville',
    'MYR': 'Myrtle Beach',
    'PIR': 'Pierre',
    'RAP': 'Rapid City',
    'FSD': 'Sioux Falls',
    'TRI': 'Bristol',
    'CHA': 'Chattanooga',
    'TYS': 'Knoxville',
    'MEM': 'Memphis',
    'BNA': 'Nashville',
    'AMA': 'Amarillo',
    'AUS': 'Austin Bergstrom International Airport',
    'CRP': 'Corpus Christi',
    'DAL': 'Dallas Love Field Airport',
    'DFW': 'Dallas/Fort Worth International Airport',
    'ELP': 'El Paso',
    'HOU': 'William B Hobby Airport',
    'IAH': 'George Bush International Airport',
    'SLC': 'Salt Lake City',
    'BTV': 'Burlington',
    'MPV': 'Montpelier',
    'RUT': 'Rutland',
    'IAD': 'Dulles',
    'PHF': 'Newport News',
    'RIC': 'Richmond',
    'ROA': 'Roanoke',
    'PSC': 'Pasco/Tri-Cities Airport',
    'SEA': 'Tacoma International Airport',
    'GEG': 'Spokane International Airport',
    'CRW': 'Charleston',
    'CKB': 'Clarksburg',
    'HTS': 'Huntington Tri-State Airport',
    'GRB': 'Green Bay',
    'MSN': 'Madison',
    'MKE': 'Milwaukee',
    'CPR': 'Casper',
    'CYS': 'Cheyenne',
    'JAC': 'Jackson Hole',
    'RKS': 'Rock Springs',
}

    
    upper_code = code.upper()
    
    if upper_code in airports:
        return airports[upper_code]
    else:
        return f"Airport with code {airport_code} not found."
    
airport_code = 'JFK'
airport_name = airport_filter(airport_code)
print(f"The airport with code {airport_code} is: {airport_name}")
# Out:
# The airport with code JFK is: John F. Kennedy International Airport

# %%
final_df['source_airport_name'] = final_df['source_airport'].apply(airport_filter)

# %%
final_df['destination_airport_name'] = final_df['destination_airport'].apply(airport_filter)

# %%
new_col_order = ['airline', 'airline_ID', 'source_airport_name', 'source_airport', 'source_airport_ID', 'destination_airport_name', 'destination_airport', 'destination_airport_ID', 'short_plane_code', 'short_code', 'capacity']

final_df = final_df[new_col_order]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67765 entries, 0 to 67782
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   airline                   67765 non-null  object
#  1   airline_ID                67765 non-null  object
#  2   source_airport_name       67765 non-null  object
#  3   source_airport            67765 non-null  object
#  4   source_airport_ID         67765 non-null  object
#  5   destination_airport_name  67765 non-null  object
#  6   destination_airport       67765 non-null  object
#  7   destination_airport_ID    67765 non-null  object
#  8   short_plane_code          67765 non-null  object
#  9   short_code                67765 non-null  object
#  10  capacity                  67765 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.2+ MB

# %%
final_df.to_csv('routes_w_capacities.csv', index=False)

# %%
list(final_df['destination_airport_name'].unique())
# Out:
# ['Airport with code JFK not found.',
#  'O’Hare International Airport',
#  'Lambert International Airport',
#  'Fort Lauderdale-Hollywood International Airport',
#  'West Palm Beach',
#  'Fort Meyers',
#  'Tampa',
#  'Orlando',
#  'Hartsfield-Jackson Atlanta International Airport',
#  'Pensacola',
#  'Jacksonville',
#  'Los Angeles International Airport',
#  'Las Vegas McCarran International Airport',
#  'Key West International Airport',
#  'Dallas/Fort Worth International Airport',
#  'John F. Kennedy International Airport',
#  'Miami International Airport',
#  'Santa Ana',
#  'Fairbanks International Airport',
#  'Anchorage International Airport',
#  'Charlotte/Douglas International Airport',
#  'Kalamazoo-Battle Creek International Airport',
#  'Chattanooga',
#  'Cedar Rapids',
#  'Charleston',
#  'Cincinnati',
#  'Evansville',
#  'Fort Wayne',
#  'Greensboro',
#  'Greenville',
#  'Lansing',
#  'Lexington',
#  'Saginaw',
#  'Roanoke',
#  'Syracuse',
#  'Knoxville',
# ...

# %%
list(final_df['airline'].unique())
# desired_value = '\\N'

# # # Count occurrences of the desired value in the column
# count = final_df[''].value_counts().get(desired_value, 0)

# print(count)
# Out:
# ['2B',
#  '2G',
#  '2I',
#  '2J',
#  '2K',
#  '2L',
#  '2N',
#  '2O',
#  '2P',
#  '2Z',
#  '3E',
#  '3F',
#  '3G',
#  '3H',
#  '3J',
#  '3K',
#  '3L',
#  '3M',
#  '3O',
#  '3P',
#  '3R',
#  '3S',
#  '3U',
#  '4B',
#  '4D',
#  '4E',
#  '4G',
#  '4H',
#  '4K',
#  '4M',
#  '4N',
#  '4O',
#  '4Q',
#  '4T',
#  '4U',
#  '4W',
#  '4Y',
#  '5C',
#  '5G',
#  '5H',
#  '5J',
#  '5M',
#  '5N',
#  '5P',
#  '5Q',
#  '5T',
#  '5U',
#  '5Z',
#  '6E',
#  '6H',
#  '6I',
#  '6L',
#  '6R',
#  '6T',
#  '6W',
#  '6Y',
#  '7C',
#  '7E',
#  '7F',
#  '7G',
#  '7H',
#  '7I',
#  '7J',
#  '7M',
#  '7P',
#  '7R',
#  '7S',
#  '8B',
#  '8D',
#  '8E',
#  '8I',
#  '8L',
#  '8M',
#  '8P',
#  '8Q',
#  '8R',
#  '8T',
#  '8U',
#  '8V',
#  '9C',
#  '9D',
#  '9E',
#  '9K',
#  '9M',
#  '9N',
#  '9Q',
#  '9R',
#  '9U',
#  '9V',
#  '9W',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'A8',
#  'A9',
#  'AA',
#  'AB',
#  'ABJ',
#  'AC',
#  'AD',
#  'AE',
#  'AF',
#  'AH',
#  'AI',
#  'AK',
#  'AM',
#  'AP',
#  'AR',
#  'AS',
#  'AT',
# ...
